# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/content/Advertising.csv")

# %%
df.head()
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
plt.scatter(df['radio'],df['sales'])
plt.xlabel('radio')
plt.ylabel('sales')
# Out:
# Text(0, 0.5, 'sales')

# %%
X = df.iloc[:,0:1]
y = df.iloc[:,-1]

# %%
X
# Out:
#      Unnamed: 0
# 0             1
# 1             2
# 2             3
# 3             4
# 4             5
# ..          ...
# 195         196
# 196         197
# 197         198
# 198         199
# 199         200
#
# [200 rows x 1 columns]

# %%
y
# Out:
# 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
#        ...
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: sales, Length: 200, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=2)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
X_test
# Out:
#      Unnamed: 0
# 112         113
# 29           30
# 182         183
# 199         200
# 193         194
# 85           86
# 10           11
# 54           55
# 115         116
# 35           36
# 12           13
# 92           93
# 13           14
# 126         127
# 174         175
# 2             3
# 44           45
# 3             4
# 113         114
# 14           15
# 23           24
# 25           26
# 6             7
# 134         135
# 165         166
# 173         174
# 45           46
# 65           66
# 48           49
# 122         123
# 178         179
# 64           65
# 9            10
# 57           58
# 78           79
# 71           72
# 128         129
# 176         177
# 131         132
# 53           54
# 137         138
# 163         164
# 111         112
# 123         124
# 109         110
# 141         142
# 41           42
# 130         131
# 140         141
# 5             6
# 159         160
# 100         101
# 11           12
# 187         188
# 24           25
# 89           90
# 66           67
# 8             9
# 172         173
# 175         176

# %%
y_test
# Out:
# 112    14.1
# 29     10.5
# 182     8.7
# 199    13.4
# 193    19.6
# 85     15.2
# 10      8.6
# 54     20.2
# 115    12.6
# 35     12.8
# 12      9.2
# 92     19.4
# 13      9.7
# 126     6.6
# 174    11.5
# 2       9.3
# 44      8.5
# 3      18.5
# 113    15.9
# 14     19.0
# 23     15.5
# 25     12.0
# 6      11.8
# 134    10.8
# 165    11.9
# 173    11.7
# 45     14.9
# 65      9.3
# 48     14.8
# 122    11.6
# 178    11.8
# 64     18.0
# 9      10.6
# 57     13.2
# 78      5.3
# 71     12.4
# 128    24.7
# 176    20.2
# 131    12.7
# 53     21.2
# 137    20.8
# 163    18.0
# 111    21.8
# 123    15.2
# 109    19.8
# 141    19.2
# 41     17.1
# 130     1.6
# 140    10.9
# 5       7.2
# 159    12.9
# 100    11.7
# 11     17.4
# 187    17.3
# 24      9.7
# 89     16.7
# 66      9.5
# 8       4.8
# 172     7.6
# 175    27.0
# Name: sales, dtype: float64

# %%
lr.predict(X_test.iloc[0].values.reshape(-1,1))
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([14.00388184])

# %%
lr.predict(X_test.values.reshape(-1,1))
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([14.00388184, 15.35839204, 12.86152384, 12.58409404, 12.68201044,
#        14.44450564, 15.66846064, 14.95040704, 13.95492364, 15.26047564,
#        15.63582184, 14.33026984, 15.61950244, 13.77541024, 12.99207904,
#        15.79901584, 15.11360104, 15.78269644, 13.98756244, 15.60318304,
#        15.45630844, 15.42366964, 15.73373824, 13.64485504, 13.13895364,
#        13.00839844, 15.09728164, 14.77089364, 15.04832344, 13.84068784,
#        12.92680144, 14.78721304, 15.68478004, 14.90144884, 14.55874144,
#        14.67297724, 13.74277144, 12.95944024, 13.69381324, 14.96672644,
#        13.59589684, 13.17159244, 14.02020124, 13.82436844, 14.05284004,
#        13.53061924, 15.16255924, 13.71013264, 13.54693864, 15.75005764,
#        13.23687004, 14.19971464, 15.65214124, 12.77992684, 15.43998904,
#        14.37922804, 14.75457424, 15.70109944, 13.02471784, 12.97575964])

# %%
y_test.values
# Out:
# array([14.1, 10.5,  8.7, 13.4, 19.6, 15.2,  8.6, 20.2, 12.6, 12.8,  9.2,
#        19.4,  9.7,  6.6, 11.5,  9.3,  8.5, 18.5, 15.9, 19. , 15.5, 12. ,
#        11.8, 10.8, 11.9, 11.7, 14.9,  9.3, 14.8, 11.6, 11.8, 18. , 10.6,
#        13.2,  5.3, 12.4, 24.7, 20.2, 12.7, 21.2, 20.8, 18. , 21.8, 15.2,
#        19.8, 19.2, 17.1,  1.6, 10.9,  7.2, 12.9, 11.7, 17.4, 17.3,  9.7,
#        16.7,  9.5,  4.8,  7.6, 27. ])

# %%
X_test
# Out:
#      Unnamed: 0
# 112         113
# 29           30
# 182         183
# 199         200
# 193         194
# 85           86
# 10           11
# 54           55
# 115         116
# 35           36
# 12           13
# 92           93
# 13           14
# 126         127
# 174         175
# 2             3
# 44           45
# 3             4
# 113         114
# 14           15
# 23           24
# 25           26
# 6             7
# 134         135
# 165         166
# 173         174
# 45           46
# 65           66
# 48           49
# 122         123
# 178         179
# 64           65
# 9            10
# 57           58
# 78           79
# 71           72
# 128         129
# 176         177
# 131         132
# 53           54

# %%
y_test
# Out:
# 112    14.1
# 29     10.5
# 182     8.7
# 199    13.4
# 193    19.6
# 85     15.2
# 10      8.6
# 54     20.2
# 115    12.6
# 35     12.8
# 12      9.2
# 92     19.4
# 13      9.7
# 126     6.6
# 174    11.5
# 2       9.3
# 44      8.5
# 3      18.5
# 113    15.9
# 14     19.0
# 23     15.5
# 25     12.0
# 6      11.8
# 134    10.8
# 165    11.9
# 173    11.7
# 45     14.9
# 65      9.3
# 48     14.8
# 122    11.6
# 178    11.8
# 64     18.0
# 9      10.6
# 57     13.2
# 78      5.3
# 71     12.4
# 128    24.7
# 176    20.2
# 131    12.7
# 53     21.2
# Name: sales, dtype: float64

# %%
plt.scatter(df['radio'],df['sales'])
plt.plot(X_train,lr.predict(X_train),color='red')
plt.xlabel('radio')
plt.ylabel('sales')
# Out:
# Text(0, 0.5, 'sales')

# %%
m = lr.coef_

# %%
b = lr.intercept_

# %%
# y = mx + b

m * 75 + b
# Out:
# array([14.43253116])
